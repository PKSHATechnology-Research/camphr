# %%
import spacy
nlp = spacy.load("en_udify")
doc = nlp("Udify is a BERT based dependency parser")
spacy.displacy.render(doc)
# Out:
# /Users/yohei_tamura/work/camphr/pkgs/en_udify-0.5/.venv/lib/python3.7/site-packages/allennlp/data/token_indexers/token_indexer.py:119: FutureWarning: Using a Field with pad_token_sequence, which will be depreciated in 1.0.0.Please implement as_padded_tensor instead.
#   FutureWarning,
# Encountered the logits key in the model's return dictionary which couldn't be split by the batch size. Key will be ignored.
# Encountered the class_probabilities key in the model's return dictionary which couldn't be split by the batch size. Key will be ignored.
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c2e756bca13d464ca04aab2262d934ba-0" class="displacy" width="1275" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Udify</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">BERT</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">based</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">dependency</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">parser</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c2e756bca13d464ca04aab2262d934ba-0-0" stroke-width="2px" d="M70,439.5 C70,2.0 1100.0,2.0 1100.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c2e756bca13d464ca04aab2262d934ba-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,441.5 L62,429.5 78,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c2e756bca13d464ca04aab2262d934ba-0-1" stroke-width="2px" d="M245,439.5 C245,89.5 1095.0,89.5 1095.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c2e756bca13d464ca04aab2262d934ba-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cop</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,441.5 L237,429.5 253,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c2e756bca13d464ca04aab2262d934ba-0-2" stroke-width="2px" d="M420,439.5 C420,177.0 1090.0,177.0 1090.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c2e756bca13d464ca04aab2262d934ba-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,441.5 L412,429.5 428,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c2e756bca13d464ca04aab2262d934ba-0-3" stroke-width="2px" d="M595,439.5 C595,352.0 730.0,352.0 730.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c2e756bca13d464ca04aab2262d934ba-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl:npmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,441.5 L587,429.5 603,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c2e756bca13d464ca04aab2262d934ba-0-4" stroke-width="2px" d="M770,439.5 C770,264.5 1085.0,264.5 1085.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c2e756bca13d464ca04aab2262d934ba-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,441.5 L762,429.5 778,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c2e756bca13d464ca04aab2262d934ba-0-5" stroke-width="2px" d="M945,439.5 C945,352.0 1080.0,352.0 1080.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c2e756bca13d464ca04aab2262d934ba-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,441.5 L937,429.5 953,429.5" fill="currentColor"/>
# </g>
# </svg>

# %%
    >>> doc = nlp("Deutsch kann so wie es ist analysiert werden")
    >>> spacy.displacy.render(doc)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="99dd592c8a9a4392bb028b1dee27e99e-0" class="displacy" width="1450" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Deutsch</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">kann</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">so</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">wie</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">es</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">ist</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">analysiert</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">werden</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-99dd592c8a9a4392bb028b1dee27e99e-0-0" stroke-width="2px" d="M70,439.5 C70,2.0 1100.0,2.0 1100.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-99dd592c8a9a4392bb028b1dee27e99e-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj:pass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,441.5 L62,429.5 78,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-99dd592c8a9a4392bb028b1dee27e99e-0-1" stroke-width="2px" d="M245,439.5 C245,89.5 1095.0,89.5 1095.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-99dd592c8a9a4392bb028b1dee27e99e-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,441.5 L237,429.5 253,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-99dd592c8a9a4392bb028b1dee27e99e-0-2" stroke-width="2px" d="M420,439.5 C420,177.0 915.0,177.0 915.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-99dd592c8a9a4392bb028b1dee27e99e-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,441.5 L412,429.5 428,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-99dd592c8a9a4392bb028b1dee27e99e-0-3" stroke-width="2px" d="M595,439.5 C595,264.5 910.0,264.5 910.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-99dd592c8a9a4392bb028b1dee27e99e-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,441.5 L587,429.5 603,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-99dd592c8a9a4392bb028b1dee27e99e-0-4" stroke-width="2px" d="M770,439.5 C770,352.0 905.0,352.0 905.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-99dd592c8a9a4392bb028b1dee27e99e-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,441.5 L762,429.5 778,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-99dd592c8a9a4392bb028b1dee27e99e-0-5" stroke-width="2px" d="M945,439.5 C945,352.0 1080.0,352.0 1080.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-99dd592c8a9a4392bb028b1dee27e99e-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,441.5 L937,429.5 953,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-99dd592c8a9a4392bb028b1dee27e99e-0-6" stroke-width="2px" d="M1120,439.5 C1120,352.0 1255.0,352.0 1255.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-99dd592c8a9a4392bb028b1dee27e99e-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux:pass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1255.0,441.5 L1263.0,429.5 1247.0,429.5" fill="currentColor"/>
# </g>
# </svg>

# %%
    >>> from camphr.pipelines import load_udify
    >>> nlp = load_udify("ja", punct_chars=["。"])
    >>> doc = nlp("日本語も解析可能です")
    >>> spacy.displacy.render(doc)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ja" id="3c8d596047b94b3f85c762bd6271a776-0" class="displacy" width="925" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">日本語</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">も</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">解析</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">可能</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">です</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3c8d596047b94b3f85c762bd6271a776-0-0" stroke-width="2px" d="M70,177.0 C70,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3c8d596047b94b3f85c762bd6271a776-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3c8d596047b94b3f85c762bd6271a776-0-1" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3c8d596047b94b3f85c762bd6271a776-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M220.0,179.0 L228.0,167.0 212.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3c8d596047b94b3f85c762bd6271a776-0-2" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3c8d596047b94b3f85c762bd6271a776-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-3c8d596047b94b3f85c762bd6271a776-0-3" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-3c8d596047b94b3f85c762bd6271a776-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,179.0 L753.0,167.0 737.0,167.0" fill="currentColor"/>
# </g>
# </svg>
